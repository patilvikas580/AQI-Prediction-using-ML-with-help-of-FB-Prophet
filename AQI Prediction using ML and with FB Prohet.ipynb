# %%
import numpy as np
import pandas as pd

# %%
#loading data from csv file to pandas data frame
#here "air quality data" is random name we can use any name
#pd.read_csv is a function which is used to read the data from csv file
#the file destination is provided
air_quality_data=pd.read_csv('/content/AirQualityUCI.csv')

# %%
#print first five rows of the data frame
#air_quality_data.head() is use to print the first five rows of the data frame
air_quality_data.head()
# Out:
#                                                                                                             Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;
# 10/03/2004;18.00.00;2            6;1360;150;11                 9;1046;166;1056;113;1692;1268;13 6;48 9;0                                                7578;;
# 10/03/2004;19.00.00;2;1292;112;9 4;955;103;1174;92;1559;972;13 3;47                             7;0  7255;;                                                NaN
# 10/03/2004;20.00.00;2            2;1402;88;9                   0;939;131;1140;114;1555;1074;11  9;54 0;0                                                7502;;
# 10/03/2004;21.00.00;2            2;1376;80;9                   2;948;172;1092;122;1584;1203;11  0;60 0;0                                                7867;;
# ...

# %%
#as above data is not in serial order
#air_quality_data=pd.read_csv('/content/AirQualityUCI.csv',sep=';') we will use this to print the data correctly
air_quality_data=pd.read_csv('/content/AirQualityUCI.csv',sep=';')

# %%
#now again printing the data whether it is printing right or not
air_quality_data.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# ...

# %%
#as we see here the decimal is in the comma so we will conver this comma to the decimal value
air_quality_data=pd.read_csv('/content/AirQualityUCI.csv',sep=';',decimal=',')

# %%
#again printing the value whether decimal is separated or not
air_quality_data.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %%
#as we can see there is coloumn which is unnamed
#we will remove this column
#we will slice the database
air_quality_data=air_quality_data.iloc[:,:-2]

# %%
air_quality_data.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
#now we will print last five rows
air_quality_data.tail()
# Out:
#      Date Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 9466  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9467  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9468  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9469  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9470  NaN  NaN     NaN          NaN       NaN       NaN            NaN
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T  RH  AH
# 9466      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9467      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9468      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9469      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9470      NaN           NaN      NaN           NaN          NaN NaN NaN NaN

# %%
#now we will slice the last rows and coloumns
#this will assign the following rows into the air_qaulity_data
air_quality_data=air_quality_data.head(9357)

# %%
#now we will print last five rows
air_quality_data.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# ...

# %% [markdown]
# **here we have done data processing**

# %%
#getting some info of data
air_quality_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
#checking the number of missing values
air_quality_data.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# **there is no missing values![111.png](data:image/png;base64,...)**

# %%
#counting the number of times -200 appears
air_quality_data.isin([-200]).sum(axis=0)
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %% [markdown]
# **handling the missing values**

# %%
#now we will handle the above missing values
#now we will convert all -200 to NAN
#after conversion we will convert all NAN values with mean of that particular coloumn
air_quality_data=air_quality_data.replace(to_replace=-200,value=np.NaN)

# %%
air_quality_data.isnull().sum()
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %% [markdown]
# this shows actual no of missing values

# %%
air_quality_data.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005  10.00.00     3.1       1314.0       NaN      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0       NaN      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0       NaN      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0       NaN       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0       NaN      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# ...

# %% [markdown]
# ### **now we will convert the NaN values to the mean values of that table**

# %%
air_quality_data.mean()
# Out:
# <ipython-input-19-d7366ba731bb>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   air_quality_data.mean()
# CO(GT)              2.152750
# PT08.S1(CO)      1099.833166
# NMHC(GT)          218.811816
# C6H6(GT)           10.083105
# PT08.S2(NMHC)     939.153376
# NOx(GT)           246.896735
# PT08.S3(NOx)      835.493605
# NO2(GT)           113.091251
# PT08.S4(NO2)     1456.264598
# PT08.S5(O3)      1022.906128
# T                  18.317829
# RH                 49.234201
# AH                  1.025530
# dtype: float64

# %%
#replace the missing value with mean values of each coloumn
air_quality_data=air_quality_data.fillna(air_quality_data.mean())
# Out:
# <ipython-input-20-c4bae333770b>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   air_quality_data=air_quality_data.fillna(air_quality_data.mean())

# %%
air_quality_data.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)    NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005  10.00.00     3.1       1314.0  218.811816      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0  218.811816      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0  218.811816      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0  218.811816       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0  218.811816      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# ...

# %% [markdown]
# **as we can see all the NaN values are replaced with mean values**

# %%
air_quality_data.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# **two task can be performed on this dataset**
#
# **1.Forecasting**
# **2.Regresion**

# %%
#C6H6(GT)         0 PT08.S2(NMHC)    0NOx(GT)          0 PT08.S4(NO2)  0
#if we give all these values as input values and predit "CO(GT)" then it will be called as rgression
#and if we provide Date             0 Time             0  values it will be called forecast
#forecasting with FB algorithm is the model that we are using

# %% [markdown]
# converttin the date into format like

# %%
#now the values are stored into date_info
date_info=pd.to_datetime(air_quality_data['Date'])
# Out:
# <ipython-input-24-21f69ac99782>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   date_info=pd.to_datetime(air_quality_data['Date'])

# %%
print(date_info)
# Out:
# 0      2004-10-03
# 1      2004-10-03
# 2      2004-10-03
# 3      2004-10-03
# 4      2004-10-03
#           ...
# 9352   2005-04-04
# 9353   2005-04-04
# 9354   2005-04-04
# 9355   2005-04-04
# 9356   2005-04-04
# Name: Date, Length: 9357, dtype: datetime64[ns]

# %%
time_info=air_quality_data['Time']

# %%
print(time_info)
# Out:
# 0       18.00.00
# 1       19.00.00
# 2       20.00.00
# 3       21.00.00
# 4       22.00.00
#           ...
# 9352    10.00.00
# 9353    11.00.00
# 9354    12.00.00
# 9355    13.00.00
# 9356    14.00.00
# Name: Time, Length: 9357, dtype: object

# %%
time_info.apply(lambda x:x.replace('.',':'))
# Out:
# 0       18:00:00
# 1       19:00:00
# 2       20:00:00
# 3       21:00:00
# 4       22:00:00
#           ...
# 9352    10:00:00
# 9353    11:00:00
# 9354    12:00:00
# 9355    13:00:00
# 9356    14:00:00
# Name: Time, Length: 9357, dtype: object

# %%
#now we will check type of data of date info && time info
print(type(date_info))
print(type(time_info))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# serire data is one row one coloumn

# %%
#combine 2 serires to pandas frame
date_time=pd.concat([date_info,time_info],axis=1)

# %%
#printing five rows of data_time data set
date_time.head()
# Out:
#         Date      Time
# 0 2004-10-03  18.00.00
# 1 2004-10-03  19.00.00
# 2 2004-10-03  20.00.00
# 3 2004-10-03  21.00.00
# 4 2004-10-03  22.00.00

# %%
#now we check shape
date_time.shape
# Out:
# (9357, 2)

# %%
#we will combine this two coloumns in a single coloumn as per prophet algorithm
date_time['ds']=date_time['Date'].astype(str)+''+date_time['Time'].astype(str)

# %%
print(date_time)
# Out:
#            Date      Time                  ds
# 0    2004-10-03  18.00.00  2004-10-0318.00.00
# 1    2004-10-03  19.00.00  2004-10-0319.00.00
# 2    2004-10-03  20.00.00  2004-10-0320.00.00
# 3    2004-10-03  21.00.00  2004-10-0321.00.00
# 4    2004-10-03  22.00.00  2004-10-0322.00.00
# ...         ...       ...                 ...
# 9352 2005-04-04  10.00.00  2005-04-0410.00.00
# 9353 2005-04-04  11.00.00  2005-04-0411.00.00
# 9354 2005-04-04  12.00.00  2005-04-0412.00.00
# 9355 2005-04-04  13.00.00  2005-04-0413.00.00
# 9356 2005-04-04  14.00.00  2005-04-0414.00.00
#
# [9357 rows x 3 columns]

# %%
date_time.head()
# Out:
#         Date      Time                  ds
# 0 2004-10-03  18.00.00  2004-10-0318.00.00
# 1 2004-10-03  19.00.00  2004-10-0319.00.00
# 2 2004-10-03  20.00.00  2004-10-0320.00.00
# 3 2004-10-03  21.00.00  2004-10-0321.00.00
# 4 2004-10-03  22.00.00  2004-10-0322.00.00

# %%
date_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9357 non-null   datetime64[ns]
#  1   Time    9357 non-null   object
#  2   ds      9357 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 219.4+ KB

# %% [markdown]
# **We have to convert ds datatype from object to datatype date**

# %%
#empty data
data=pd.DataFrame()

# %%
#ds column is created in this data set with data from ds coloumn of date time
data['ds'] = pd.to_datetime(date_time['ds'], format="%Y-%m-%d%H.%M.%S")

# %%
print(data)
# Out:
#                       ds
# 0    2004-10-03 18:00:00
# 1    2004-10-03 19:00:00
# 2    2004-10-03 20:00:00
# 3    2004-10-03 21:00:00
# 4    2004-10-03 22:00:00
# ...                  ...
# 9352 2005-04-04 10:00:00
# 9353 2005-04-04 11:00:00
# 9354 2005-04-04 12:00:00
# 9355 2005-04-04 13:00:00
# 9356 2005-04-04 14:00:00
#
# [9357 rows x 1 columns]

# %% [markdown]
# **now we will choose one variable from coloumns and check trend of that coloumn**

# %%
#here RH variable(coloumn) is used
data['y']=air_quality_data['RH']

# %%
data.head()
# Out:
#                    ds     y
# 0 2004-10-03 18:00:00  48.9
# 1 2004-10-03 19:00:00  47.7
# 2 2004-10-03 20:00:00  54.0
# 3 2004-10-03 21:00:00  60.0
# 4 2004-10-03 22:00:00  59.6

# %%
#import prophet
from prophet import Prophet

# %%
#training the prophet model
model=Prophet()
model.fit(data)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpggowcwtk/a8dnbyfr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpggowcwtk/6rt_0rh1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79055', 'data', 'file=/tmp/tmpggowcwtk/a8dnbyfr.json', 'init=/tmp/tmpggowcwtk/6rt_0rh1.json', 'output', 'file=/tmp/tmpggowcwtk/prophet_modelnw3hrg89/prophet_model-20240423054323.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:43:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:43:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
#now we will predict the future trend using prophet
future = model.make_future_dataframe(periods=365,freq='H')
future.tail()
# Out:
#                       ds
# 9717 2005-12-19 00:00:00
# 9718 2005-12-19 01:00:00
# 9719 2005-12-19 02:00:00
# 9720 2005-12-19 03:00:00
# 9721 2005-12-19 04:00:00

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                       ds       yhat  yhat_lower  yhat_upper
# 9717 2005-12-19 00:00:00  59.431287   42.662038   76.552844
# 9718 2005-12-19 01:00:00  60.810438   43.249700   77.782511
# 9719 2005-12-19 02:00:00  61.889115   43.968279   78.905077
# 9720 2005-12-19 03:00:00  62.677416   46.325323   81.324344
# 9721 2005-12-19 04:00:00  63.461402   45.434220   80.779286

# %%
fig1 = model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)
